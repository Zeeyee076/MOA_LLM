# %%
# ---------------------------------------------------------
# 0. IMPORTS
# ---------------------------------------------------------
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from datasets import load_dataset

# ---------------------------------------------------------
# 1. SETUP & CONFIGURATION
# ---------------------------------------------------------

# Define the model identifiers (NEW MODELS)
MODEL_ID_QWEN = "Qwen/Qwen2.5-3B-Instruct"           # A, F, G
MODEL_ID_GEMMA = "unsloth/Llama-3.2-3B-Instruct"     # B, D
MODEL_ID_LFM   = "unsloth/gemma-3-4b-it"             # C, E

print("Loading Dataset...")
dataset = load_dataset("glue", "sst2")
val_data = dataset["validation"].select(range(50))  # First 50 samples (change if you want)

USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(f"CUDA available: {USE_CUDA}")
print(f"Running on: {DEVICE}")
# Out:
# Loading Dataset...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# sst2/train-00000-of-00001.parquet:   0%|          | 0.00/3.11M [00:00<?, ?B/s]
# sst2/validation-00000-of-00001.parquet:   0%|          | 0.00/72.8k [00:00<?, ?B/s]
# sst2/test-00000-of-00001.parquet:   0%|          | 0.00/148k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/67349 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/872 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1821 [00:00<?, ? examples/s]
# CUDA available: True
# Running on: cuda

# %%
# ---------------------------------------------------------
# 2. MODEL LOADING
# ---------------------------------------------------------

def load_model_and_tokenizer(model_id):
    """
    Load model and tokenizer using AutoClasses, ensuring pad token is set.
    Models stay on CPU; we'll move them to GPU only when needed.
    """
    print(f"Loading {model_id}...")
    tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)

    model = AutoModelForCausalLM.from_pretrained(
        model_id,
        torch_dtype=torch.float16 if USE_CUDA else torch.float32,
        trust_remote_code=True
    )
    model.eval()

    # Ensure pad token is set
    if tokenizer.pad_token_id is None:
        tokenizer.pad_token_id = tokenizer.eos_token_id

    return model, tokenizer

print("Loading Models (This may take a moment)...")
model_qwen, tok_qwen   = load_model_and_tokenizer(MODEL_ID_QWEN)
model_gemma, tok_gemma = load_model_and_tokenizer(MODEL_ID_GEMMA)
model_lfm, tok_lfm     = load_model_and_tokenizer(MODEL_ID_LFM)

# Map Logical Agents to Physical Model/Tokenizer pairs
# Architecture:
# Layer 1: A(Qwen), B(Gemma), C(LFM)
# Layer 2: D(Gemma), E(LFM), F(Qwen)
# Layer 3: G(Qwen)
agents = {
    "A": (model_qwen,  tok_qwen),
    "B": (model_gemma, tok_gemma),
    "C": (model_lfm,   tok_lfm),
    "D": (model_gemma, tok_gemma),
    "E": (model_lfm,   tok_lfm),
    "F": (model_qwen,  tok_qwen),
    "G": (model_qwen,  tok_qwen),
}
# Out:
# Loading Models (This may take a moment)...
# Loading Qwen/Qwen2.5-3B-Instruct...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.97G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# Loading unsloth/Llama-3.2-3B-Instruct...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/890 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# Loading unsloth/gemma-3-4b-it...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/670 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.64G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/210 [00:00<?, ?B/s]

# %%
# ---------------------------------------------------------
# 3. HELPER FUNCTIONS
# ---------------------------------------------------------

def parse_label_and_reason(raw_text):
    """
    Parse model output into:
    - label_int: 1 (Positive), 0 (Negative), or -1 (Unknown)
    - label_str: 'Positive', 'Negative', or 'Unknown'
    - reason_str: explanation text (may be whole raw_text as fallback)

    Expected (but not strictly required) format:
        Label: Positive
        Reason: ...
    """
    if not raw_text:
        return -1, "Unknown", ""

    # Split into non-empty lines
    lines = [l.strip() for l in raw_text.splitlines() if l.strip()]
    if not lines:
        return -1, "Unknown", ""

    # First line -> label
    first_line = lines[0].lower()
    if "positive" in first_line and "negative" not in first_line:
        label_int = 1
        label_str = "Positive"
    elif "negative" in first_line and "positive" not in first_line:
        label_int = 0
        label_str = "Negative"
    else:
        label_int = -1
        label_str = "Unknown"

    # Everything after first line -> reason
    if len(lines) > 1:
        reason_lines = []
        for l in lines[1:]:
            # strip "Reason:" prefix if present
            if l.lower().startswith("reason:"):
                l = l.split(":", 1)[1].strip()
            reason_lines.append(l)
        reason_str = " ".join(reason_lines).strip()
    else:
        reason_str = ""

    # Fallback: if reason is empty, keep full raw output as reason
    if not reason_str:
        reason_str = raw_text.strip()

    return label_int, label_str, reason_str


def query_agent(agent_name, messages, max_new_tokens=128):
    """
    Query a specific agent.
    On GPU: temporarily move the model to CUDA for this call, then back to CPU
    to avoid keeping multiple large models in VRAM at once.
    """
    model, tokenizer = agents[agent_name]

    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")

    # Move model to the right device for this call
    model.to(device)

    # Build chat prompt as plain string (respecting model's chat template)
    prompt_str = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    # Make sure inputs are on the same device as the model
    inputs = tokenizer(prompt_str, return_tensors="pt").to(device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=False,         # greedy
            pad_token_id=tokenizer.pad_token_id
        )

    generated_text = tokenizer.decode(
        outputs[0][inputs["input_ids"].shape[-1]:],
        skip_special_tokens=True
    ).strip()

    # Move model back to CPU to free VRAM for other models
    if use_cuda:
        model.to("cpu")
        torch.cuda.empty_cache()

    return generated_text

# %%
# ---------------------------------------------------------
# 4. MOA ARCHITECTURE IMPLEMENTATION
# ---------------------------------------------------------

results = []

print("\n--- Starting 3-Layer MOA Inference Pipeline ---\n")

for i, item in enumerate(val_data):
    text = item['sentence']
    true_label = item['label']          # 0/1
    true_label_str = "positive" if true_label == 1 else "negative"

    print(f"Sample {i+1}: '{text}' (True: {true_label_str})")

    # ==========================================
    # LAYER 1: Base Agents (A, B, C)
    # Each returns label + reasoning
    # ==========================================

    l1_system = (
        "You are a sentiment classifier for movie reviews.\n"
        "You MUST output EXACTLY TWO lines and nothing else.\n\n"
        "Line 1 format:\n"
        "Label: Positive\n"
        "OR\n"
        "Label: Negative\n\n"
        "Line 2 format:\n"
        "Reason: <one short sentence explaining why>\n\n"
        "Example output:\n"
        "Label: Negative\n"
        "Reason: The review describes the film as boring and disappointing.\n\n"
        "Always include BOTH lines. Never omit the Reason line."
    )
    l1_user = f"Review: {text}\n\nClassify the sentiment."

    l1_messages = [
        {"role": "system", "content": l1_system},
        {"role": "user", "content": l1_user}
    ]

    raw_A = query_agent("A", l1_messages, max_new_tokens=64)
    raw_B = query_agent("B", l1_messages, max_new_tokens=64)
    raw_C = query_agent("C", l1_messages, max_new_tokens=64)

    A_label_int, A_label_str, A_reason = parse_label_and_reason(raw_A)
    B_label_int, B_label_str, B_reason = parse_label_and_reason(raw_B)
    C_label_int, C_label_str, C_reason = parse_label_and_reason(raw_C)

    # ==========================================
    # LAYER 2: Secondary Agents (D, E, F)
    # D uses A, E uses B, F uses C
    # ==========================================

    def build_l2_messages(prev_agent_name, prev_label_str, prev_reason):
        sys_msg = (
            "You are a second-layer sentiment analyst.\n"
            "You see the original review and a previous model's prediction and its reasoning.\n"
            "You may either confirm or correct the previous label.\n"
            "You MUST output EXACTLY TWO lines and nothing else.\n\n"
            "Line 1 format:\n"
            "Label: Positive\n"
            "OR\n"
            "Label: Negative\n\n"
            "Line 2 format:\n"
            "Reason: <one short sentence explaining your decision>\n\n"
            "Example output:\n"
            "Label: Positive\n"
            "Reason: The analysis is correct and the review expresses clear enjoyment.\n\n"
            "Always include BOTH lines."
        )
        user_msg = (
            f"Original review: {text}\n\n"
            f"Previous agent {prev_agent_name} predicted: {prev_label_str}\n"
            f"Reason from {prev_agent_name}: {prev_reason}\n\n"
            "Now, reconsider the sentiment and output your final label and reasoning."
        )
        return [
            {"role": "system", "content": sys_msg},
            {"role": "user", "content": user_msg}
        ]

    raw_D = query_agent("D", build_l2_messages("A", A_label_str, A_reason), max_new_tokens=64)
    raw_E = query_agent("E", build_l2_messages("B", B_label_str, B_reason), max_new_tokens=64)
    raw_F = query_agent("F", build_l2_messages("C", C_label_str, C_reason), max_new_tokens=64)

    D_label_int, D_label_str, D_reason = parse_label_and_reason(raw_D)
    E_label_int, E_label_str, E_reason = parse_label_and_reason(raw_E)
    F_label_int, F_label_str, F_reason = parse_label_and_reason(raw_F)

    # ==========================================
    # LAYER 3: Aggregator (G)
    # Aggregates D/E/F, sees all labels + reasons + original text
    # ==========================================

    l3_system = (
        "You are an aggregator in a multi-agent sentiment system.\n"
        "You MUST output EXACTLY TWO lines and NOTHING ELSE.\n\n"
        "CRITICAL RULE:\n"
        "You are ONLY allowed to output one of the following labels:\n"
        "  Label: Positive\n"
        "  Label: Negative\n"
        "You are NOT allowed to output any other label.\n\n"
        "FORMAT:\n"
        "Line 1: Label: Positive   OR   Label: Negative\n"
        "Line 2: Reason: <one short sentence explaining your decision>\n\n"
        "Example:\n"
        "Label: Positive\n"
        "Reason: The majority of agents identify a positive sentiment and the review expresses clear enjoyment.\n\n"
        "IMPORTANT: Never output anything other than 'Positive' or 'Negative'."
    )

    l3_user = (
        f"Original review: {text}\n\n"
        f"Agent D -> Label: {D_label_str}, Reason: {D_reason}\n"
        f"Agent E -> Label: {E_label_str}, Reason: {E_reason}\n"
        f"Agent F -> Label: {F_label_str}, Reason: {F_reason}\n\n"
        "Based on these, choose the best final sentiment label and explain briefly."
    )

    l3_messages = [
        {"role": "system", "content": l3_system},
        {"role": "user", "content": l3_user}
    ]

    final_raw = query_agent("G", l3_messages, max_new_tokens=64)
    final_label_int, final_label_str, final_reason = parse_label_and_reason(final_raw)

    is_correct = (final_label_int == true_label)

    # Store Result (with reasoning track)
    results.append({
        "text": text,
        "true_label": true_label_str,
        "L1": {
            "A": {"raw": raw_A, "label": A_label_str, "reason": A_reason},
            "B": {"raw": raw_B, "label": B_label_str, "reason": B_reason},
            "C": {"raw": raw_C, "label": C_label_str, "reason": C_reason},
        },
        "L2": {
            "D": {"raw": raw_D, "label": D_label_str, "reason": D_reason},
            "E": {"raw": raw_E, "label": E_label_str, "reason": E_reason},
            "F": {"raw": raw_F, "label": F_label_str, "reason": F_reason},
        },
        "Final": {
            "raw": final_raw,
            "label": final_label_str,
            "reason": final_reason,
        },
        "Correct": is_correct
    })

    # --------- Detailed trace printing ---------
    print("\n--- Layer 1 (Base Agents) ---")
    print(f"   A -> Label: {A_label_str}, Reason: {A_reason}")
    print(f"   B -> Label: {B_label_str}, Reason: {B_reason}")
    print(f"   C -> Label: {C_label_str}, Reason: {C_reason}")

    print("\n--- Layer 2 (Secondary Agents) ---")
    print(f"   D (from A) -> Label: {D_label_str}, Reason: {D_reason}")
    print(f"   E (from B) -> Label: {E_label_str}, Reason: {E_reason}")
    print(f"   F (from C) -> Label: {F_label_str}, Reason: {F_reason}")

    print("\n--- Layer 3 (Aggregator) ---")
    print(f"   G (final)  -> Label: {final_label_str}, Reason: {final_reason}")
    print(f"\n   ==> FINAL: {final_label_str.upper()} "
          f"[{'CORRECT' if is_correct else 'WRONG'}]  (true: {true_label_str})")
    print("-" * 80)
# Out:
# --- Starting 3-Layer MOA Inference Pipeline ---
#
# Sample 1: 'it 's a charming and often affecting journey . ' (True: positive)
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review describes the film as charming and affecting, indicating a positive sentiment.
#    B -> Label: Positive, Reason: The review uses positive adjectives like "charming" to describe the film.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses words like "charming" and "affecting", which convey a strong positive emotional tone.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review expresses admiration and emotional connection with the journey described.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: The review uses positive descriptors such as "charming" and "affecting," indicating a favorable sentiment.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 2: 'unflinchingly bleak and desperate ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review describes the film in negative terms, using words like 'unflinchingly bleak and desperate'.
#    B -> Label: Negative, Reason: The review uses words like "bleak" and "desperate", which convey a sense of hopelessness and despair.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review's use of words like 'unflinchingly bleak and desperate' suggests a strong emotional impact, implying a powerful and impactful experience.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review describes the content as unflinchingly bleak and desperate, indicating a negative and somber tone.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review describes the content as unflinchingly bleak and desperate, indicating a negative and somber tone.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 3: 'allows us to hope that nolan is poised to embark a major career as a commercial yet inventive filmmaker . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review expresses optimism about Nolan's potential for future success as a filmmaker.
#    B -> Label: Positive, Reason: The review expresses optimism about Christopher Nolan's future career prospects.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Unknown, Reason: The review is cautiously optimistic, but does not explicitly express enthusiasm or strong praise.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review expresses optimism about Nolan's potential for a successful filmmaking career.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: Agent F correctly identifies the cautious optimism as expressing a positive outlook on Nolan's future in filmmaking.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 4: 'the acting , costumes , music , cinematography and sound are all astounding given the production 's austere locales . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review highlights multiple aspects of the film positively, praising acting, costumes, music, cinematography, and sound.
#    B -> Label: Positive, Reason: The review highlights several aspects of the production as "astounding", indicating a very positive opinion.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses superlatives like "astounding" to emphasize the reviewer's high praise for the production's various elements.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review praises multiple aspects of the production without any negative comments, indicating overall satisfaction.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: The review highlights multiple positive aspects of the production using strong language, showing appreciation for its elements despite challenging conditions.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 5: 'it 's slow -- very , very slow . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review indicates that the movie is excessively slow, which is generally considered a negative aspect for most viewers.
#    B -> Label: Negative, Reason: The review describes the film as slow.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review uses strong negative language ("very, very slow") to emphasize its dissatisfaction.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review clearly expresses dissatisfaction with the speed of the product or service.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review conveys strong negative sentiment through the use of "very, very slow" to express dissatisfaction.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 6: 'although laced with humor and a few fanciful touches , the film is a refreshingly serious look at young women . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review appreciates the film's seriousness and unique approach to young women.
#    B -> Label: Positive, Reason: The review highlights the film's positive aspects, such as its humor and seriousness.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Unknown, Reason: The review balances humor and seriousness, indicating a mixed tone.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: Despite some humorous elements, the review praises the film for being a serious and refreshing look at young women.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: Agent F correctly identifies the overall positive sentiment, praising the film's serious approach to its subject matter.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 7: 'a sometimes tedious film . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review indicates the film is tedious, which is a negative descriptor.
#    B -> Label: Unknown, Reason: The review uses a neutral adjective "tedious" to describe the film.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Unknown, Reason: The review uses a neutral descriptor "sometimes" to balance the negative connotation of "tedious".
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review indicates the film is sometimes tedious, suggesting an overall negative experience.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review describes the film as "sometimes tedious," which implies an overall negative experience.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 8: 'or doing last year 's taxes with your ex-wife . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review is incomplete but seems to express frustration or dissatisfaction.
#    B -> Label: Negative, Reason: The review implies a negative experience with a past relationship.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The mention of "with your ex-wife" implies a negative context and connotation.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review conveys a negative experience associated with tax preparation, implying difficulty or discomfort.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review suggests a negative experience related to tax preparation, likely due to the association with an ex-wife.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 9: 'you do n't have to know about music to appreciate the film 's easygoing blend of comedy and romance . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review suggests that the film is accessible without requiring knowledge of music, implying it's enjoyable for a wide audience.
#    B -> Label: Positive, Reason: The review uses positive adjectives like "easygoing" and "appreciate" to describe the film.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review implies that the film is enjoyable, despite mentioning it doesn't require knowledge of music, suggesting a broad appeal.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review suggests that the film is accessible without requiring knowledge of music, implying it is enjoyable for a wide audience.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: The review indicates the film is accessible and enjoyable, regardless of musical knowledge.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 10: 'in exactly 89 minutes , most of which passed as slowly as if i 'd been sitting naked on an igloo , formula 51 sank from quirky to jerky to utter turkey . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review describes the film as slow, uninteresting, and ultimately bad.
#    B -> Label: Negative, Reason: The reviewer uses strong negative language, such as "sank", "jerky", and "turkey", to describe the film.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses hyperbolic language to express a humorous, tongue-in-cheek tone, indicating a playful and lighthearted sentiment.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review strongly criticizes the movie's pacing and quality, describing it negatively throughout.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review contains strong criticism of the movie's pacing and quality, using negative descriptors like "slowly," "jerky," and "utter turkey."
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 11: 'the mesmerizing performances of the leads keep the film grounded and keep the audience riveted . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review highlights the captivating performances as a positive aspect that holds the audience's attention.
#    B -> Label: Positive, Reason: The review highlights the strong performances of the leads, indicating a positive aspect of the film.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses words like "mesmerizing" and "riveted" to convey a strong positive impression.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review praises the performances as grounding and engaging, indicating a positive sentiment.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: The review highlights positive aspects such as "mesmerizing performances" and how they keep the audience engaged, which indicates a favorable view.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 12: 'it takes a strange kind of laziness to waste the talents of robert forster , anne meara , eugene levy , and reginald veljohnson all in the same movie . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review criticizes the movie for underutilizing talented actors.
#    B -> Label: Negative, Reason: The reviewer criticizes the film for wasting the talents of its cast.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review praises the movie for featuring a talented cast.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review criticizes the movie for not utilizing talented actors effectively, indicating disappointment and frustration.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review criticizes the movie for not effectively utilizing talented actors, indicating disappointment and frustration.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 13: '... the film suffers from a lack of humor ( something needed to balance out the violence ) ... ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review indicates the film lacks humor, which is seen as a negative aspect.
#    B -> Label: Negative, Reason: The review mentions a lack of humor, which is a crucial element for balance in the film.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review explicitly states the film suffers from a lack of humor, which is a significant drawback.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review indicates dissatisfaction with the film due to a perceived lack of humor that was needed to balance out the violence.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review criticizes the film for lacking humor, which is seen as a negative aspect.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 14: 'we root for ( clara and paul ) , even like them , though perhaps it 's an emotion closer to pity . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review expresses pity for the characters rather than positive emotions, indicating a negative sentiment.
#    B -> Label: Positive, Reason: The reviewer expresses affection and investment in the characters, indicating a positive emotional connection.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Unknown, Reason: The review expresses a mix of emotions, including pity, but also acknowledges a rooting interest in the characters.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review expresses a negative sentiment towards Clara and Paul, indicating pity rather than genuine liking.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review expresses pity towards Clara and Paul, which is a negative sentiment.
#
#    ==> FINAL: NEGATIVE [WRONG]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 15: 'even horror fans will most likely not find what they 're seeking with trouble every day ; the movie lacks both thrills and humor . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review criticizes the movie for lacking both thrills and humor, indicating it is unsatisfactory for even horror fans.
#    B -> Label: Negative, Reason: The review expresses disappointment with the movie's lack of thrills and humor.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review criticizes the movie for lacking both thrills and humor, indicating it is unsatisfactory.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review criticizes the movie for lacking thrills and humor, indicating a negative experience.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review consistently criticizes the movie for lacking both thrills and humor, indicating dissatisfaction.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 16: 'a gorgeous , high-spirited musical from india that exquisitely blends music , dance , song , and high drama . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review praises the film's beauty, musical elements, and integration of various art forms.
#    B -> Label: Positive, Reason: The review uses positive adjectives such as "gorgeous", "high-spirited", and "exquisitely" to describe the film.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses positive adjectives like "gorgeous" and "exquisitely" to describe the musical, indicating overall enthusiasm.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review expresses admiration for the musical's qualities without any negative comments.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: The review consistently uses positive language to describe the musical, highlighting its various strengths without any negative aspects mentioned.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 17: 'the emotions are raw and will strike a nerve with anyone who 's ever had family trauma . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review highlights emotionally impactful qualities that resonate with those experiencing family trauma.
#    B -> Label: Positive, Reason: The review highlights the emotional impact of the film, suggesting it is effective in evoking strong emotions.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review implies that the emotions may be triggering for those with family trauma, suggesting a potentially distressing experience.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review praises the emotional impact of the work, suggesting it resonates deeply with those who have experienced family trauma.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review implies that the emotions may be triggering for those with family trauma, suggesting a potentially distressing experience.
#
#    ==> FINAL: NEGATIVE [WRONG]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 18: 'audrey tatou has a knack for picking roles that magnify her outrageous charm , and in this literate french comedy , she 's as morning-glory exuberant as she was in amélie . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review praises Audrey Tatou's role selection and describes her performance positively, comparing it favorably to her work in "Amélie".
#    B -> Label: Positive, Reason: The review praises Audrey Tautou's charm and compares her positively to her previous role in Amélie.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses positive adjectives like "outrageous charm" and "exuberant" to describe Audrey Tatou's performance.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review praises Audrey Tatou's role selection and compares her performance favorably to her work in "Amélie," expressing admiration.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: The review highlights Audrey Tatou's talent and positive aspects of her performance in the film.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 19: '... the movie is just a plain old monster . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review suggests the movie lacks originality and depth, describing it simply as a 'monster'.
#    B -> Label: Negative, Reason: The review uses the word "plain" to imply that the movie is unoriginal and lacks excitement.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review uses a derogatory term "plain old" to describe the movie, indicating a strong negative sentiment.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review clearly expresses disappointment and dissatisfaction with the movie.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review describes the movie as merely a "plain old monster," suggesting a lackluster and unremarkable experience, which indicates a negative sentiment.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 20: 'in its best moments , resembles a bad high school production of grease , without benefit of song . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review compares the film unfavorably to a bad high school production, indicating disappointment.
#    B -> Label: Negative, Reason: The review compares the film unfavorably to a bad high school production of Grease.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses a hyperbolic comparison to emphasize the film's shortcomings, implying a strong negative opinion.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review describes the work as resembling a poor production of Grease, indicating disappointment and criticism.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review compares the work unfavorably to a bad high school production of Grease, expressing disappointment and criticism.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 21: 'pumpkin takes an admirable look at the hypocrisy of political correctness , but it does so with such an uneven tone that you never know when humor ends and tragedy begins . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review criticizes the uneven tone which makes the humor unpredictable and confusing, leading to dissatisfaction.
#    B -> Label: Unknown, Reason: The review praises the film's theme but criticizes its tone, indicating a complex and ambivalent sentiment.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Unknown, Reason: The review acknowledges both the admirable aspect and criticism of the tone, indicating a balanced perspective.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review criticizes the uneven tone which makes the film hard to enjoy, indicating overall dissatisfaction.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review criticizes the uneven tone which makes the film hard to enjoy, indicating overall dissatisfaction.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 22: 'the iditarod lasts for days - this just felt like it did . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review suggests the experience was immersive and extended, implying enjoyment.
#    B -> Label: Negative, Reason: The reviewer implies the film was uneventful and lacking in excitement.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review implies a sense of monotony and dissatisfaction with the duration of the event.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review seems to appreciate the duration of the event without any negative connotations.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: Agent D's interpretation of the review as implying a sense of monotony and dissatisfaction aligns more closely with the overall negative sentiment.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 23: 'holden caulfield did it better . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review implies that Holden Caulfield's work is superior, suggesting dissatisfaction with the current film.
#    B -> Label: Negative, Reason: The review expresses dissatisfaction with the original film, implying it was surpassed by another.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review is ironic and sarcastic, implying admiration for Holden Caulfield's work.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review expresses disappointment by stating Holden Caulfield did a worse job than expected.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review expresses disappointment by stating Holden Caulfield did a worse job than expected.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 24: 'a delectable and intriguing thriller filled with surprises , read my lips is an original . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review describes the film as delectable, intriguing, and filled with surprises, indicating a positive sentiment.
#    B -> Label: Positive, Reason: The review uses positive adjectives like "delectable" and "intriguing" to describe the film.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses positive adjectives and phrases, but "read my lips" is a phrase often associated with a challenge or dare, which could imply a negative connotation.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review expresses enthusiasm and appreciation for the thriller's qualities and originality.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: Agent F correctly identifies the overall positive sentiment without introducing ambiguous phrases.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 25: 'seldom has a movie so closely matched the spirit of a man and his work . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review praises the movie's ability to capture the essence of a person and their achievements.
#    B -> Label: Positive, Reason: The review uses a glowing comparison to the subject's work, indicating admiration and high praise.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses a superlative phrase "seldom" to emphasize the movie's exceptional quality.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review praises how well the movie captured the essence of a person and their work.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: The reviews consistently highlight the movie's ability to capture the spirit of its subject, indicating a positive sentiment.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 26: 'nicks , seemingly uncertain what 's going to make people laugh , runs the gamut from stale parody to raunchy sex gags to formula romantic comedy . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review criticizes the film's inconsistent humor, describing it negatively as stale and lacking variety.
#    B -> Label: Negative, Reason: The review implies the film is inconsistent and fails to deliver a cohesive tone.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review criticizes the film's inconsistent humor, describing it negatively as stale and lacking variety.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review criticizes the content as varying between unengaging and inappropriate, indicating overall dissatisfaction.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: Multiple agents have identified negative aspects in the review, criticizing the film's inconsistent humor and content quality.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 27: 'the action switches between past and present , but the material link is too tenuous to anchor the emotional connections that purport to span a 125-year divide . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review criticizes the disjointed nature of the narrative, which weakens emotional engagement across different time periods.
#    B -> Label: Negative, Reason: The reviewer finds the film's narrative structure confusing and ineffective.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review criticizes the narrative's disjointedness, which suggests a lack of coherence and emotional impact.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review criticizes the disjointed narrative structure and weak emotional connection, indicating dissatisfaction with the film.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review critically evaluates the disjointed narrative structure and weak emotional connection, indicating dissatisfaction with the film.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 28: 'it 's an offbeat treat that pokes fun at the democratic exercise while also examining its significance for those who take part . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review describes the film in a positive light, praising its unique approach and examination of its subject.
#    B -> Label: Positive, Reason: The review describes the film as an "offbeat treat", indicating a positive tone.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Unknown, Reason: The review is analytical and objective, neither strongly praising nor criticizing the film.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review describes the subject as "offbeat" in a positive light, suggesting it offers a unique perspective on the democratic process.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: Agent F correctly identifies the positive aspect of the film being "offbeat" and offering a unique perspective, aligning with the overall positive sentiment expressed.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 29: 'it 's a cookie-cutter movie , a cut-and-paste job . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review criticizes the movie as lacking originality and being formulaic.
#    B -> Label: Negative, Reason: The reviewer uses negative language to describe the movie as unoriginal and lacking effort.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review uses strong negative language, such as "cookie-cutter" and "cut-and-paste job", indicating a strong criticism of the movie's originality and production quality.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review clearly expresses dissatisfaction and criticism of the movie's lack of originality.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review uses harsh criticism terms like "cookie-cutter" and "cut-and-paste job," indicating a negative sentiment towards the movie.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 30: 'i had to look away - this was god awful . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review uses harsh language like "god awful" indicating strong dislike for the movie.
#    B -> Label: Negative, Reason: The reviewer uses strong negative language, calling the film "god awful".
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review uses extremely strong language, indicating a very negative sentiment.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review strongly expresses extreme dissatisfaction with the subject.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review contains highly critical language ("god awful") that clearly indicates a negative sentiment.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 31: 'thanks to scott 's charismatic roger and eisenberg 's sweet nephew , roger dodger is one of the most compelling variations on in the company of men . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review praises Roger Dodger as one of the most compelling variations on In the Company of Men, highlighting positive aspects like Scott's charisma and Eisenberg's performance.
#    B -> Label: Positive, Reason: The review praises the film's unique take and the performances of its leads.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review uses a sarcastic tone and mocks the title "Roger Dodger", implying a negative sentiment towards the movie.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review praises the performances and describes the movie as "one of the most compelling variations," indicating a positive sentiment.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: Agent D identifies a sarcastic tone that implies a negative sentiment towards the movie.
#
#    ==> FINAL: NEGATIVE [WRONG]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 32: '... designed to provide a mix of smiles and tears , `` crossroads '' instead provokes a handful of unintentional howlers and numerous yawns . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review criticizes the film for being filled with unintentional mistakes and failing to evoke emotions.
#    B -> Label: Negative, Reason: The review expresses disappointment and frustration with the film's failure to deliver its intended emotional impact.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review criticizes the film for being filled with unintentional mistakes and failing to evoke emotions.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review criticizes the movie for causing unintentional laughter and yawns, indicating disappointment rather than enjoyment.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review highlights multiple shortcomings of the film, including unintentional mistakes and failure to engage the audience emotionally.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 33: 'a gorgeous , witty , seductive movie . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review uses positive adjectives to describe the movie.
#    B -> Label: Positive, Reason: The review uses positive adjectives such as "gorgeous" and "witty".
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses positive adjectives to describe the movie, but the tone is more playful and lighthearted, suggesting a positive overall sentiment.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review uses positive adjectives to describe the movie, indicating a favorable opinion.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: The review uses positive adjectives to describe the movie, indicating a favorable opinion.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 34: 'if the movie succeeds in instilling a wary sense of ` there but for the grace of god , ' it is far too self-conscious to draw you deeply into its world . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review criticizes the movie for being too self-conscious and failing to fully engage the viewer.
#    B -> Label: Negative, Reason: The reviewer finds the movie self-conscious and unable to draw the viewer in.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review criticizes the movie for being too self-conscious, indicating a negative opinion.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review criticizes the movie for being too self-conscious and failing to fully engage the viewer.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: Multiple agents have identified a negative sentiment towards the movie due to its perceived self-consciousness and failure to engage viewers.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 35: 'it does n't believe in itself , it has no sense of humor ... it 's just plain bored . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review criticizes the film for lacking confidence, humor, and engagement.
#    B -> Label: Negative, Reason: The reviewer expresses strong negative opinions about the film's humor and overall tone.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review explicitly states the film is "bored", indicating a strong negative sentiment.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review contains multiple criticisms and expresses boredom, indicating a negative sentiment.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review criticizes the film's lack of self-belief, humor, and describes it as "bored," clearly expressing a negative sentiment.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 36: 'a sequence of ridiculous shoot - 'em - up scenes . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review criticizes the scenes as ridiculous, indicating dissatisfaction.
#    B -> Label: Negative, Reason: The review describes the film as ridiculous, implying a negative opinion.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses the word "ridiculous" in a playful manner, suggesting a tongue-in-cheek tone.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review clearly expresses dissatisfaction with the scenes described.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review expresses dissatisfaction with the scenes described, using the term "ridiculous" in a critical context.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 37: 'the weight of the piece , the unerring professionalism of the chilly production , and the fascination embedded in the lurid topic prove recommendation enough . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review highlights positive aspects like professional production and intriguing content, warranting a recommendation.
#    B -> Label: Positive, Reason: The review uses positive adjectives such as "unerring professionalism" and "fascination".
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses phrases like "recommendation enough" and "fascination embedded", indicating strong endorsement.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review expresses enthusiasm and recommendation for the piece despite its challenging elements.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: The review conveys enthusiasm and a strong recommendation, highlighting the piece's qualities even when mentioning challenging aspects.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 38: '( w ) hile long on amiable monkeys and worthy environmentalism , jane goodall 's wild chimpanzees is short on the thrills the oversize medium demands . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review criticizes the film for being lacking in excitement despite its positive elements.
#    B -> Label: Negative, Reason: The reviewer finds the film lacking in thrills despite its engaging subject matter.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review criticizes the film for being lacking in excitement, outweighing its positive aspects.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review criticizes the movie for lacking excitement despite positive aspects mentioned.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: Multiple agents highlight the criticism of the film's lack of excitement, which is more significant than the positive elements mentioned.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 39: 'as surreal as a dream and as detailed as a photograph , as visually dexterous as it is at times imaginatively overwhelming . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review praises the film's visual aspects, describing it as both detailed and imaginative.
#    B -> Label: Positive, Reason: The review uses positive adjectives such as "surreal", "detailed", and "visually dexterous" to describe the film.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses positive adjectives like "dexterous" and "imaginatively overwhelming", indicating a generally favorable tone.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review praises multiple aspects of the subject in a complimentary manner without any negative comments.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: Multiple agents agree that the review is positive, praising various aspects of the subject without any negative comments.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 40: 'escaping the studio , piccoli is warmly affecting and so is this adroitly minimalist movie . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review describes the movie as warmly affecting and adroitly minimalist, indicating positive qualities.
#    B -> Label: Positive, Reason: The review uses positive adjectives such as "warmly affecting" and "adroitly minimalist".
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses positive adjectives like "warmly" and "affecting", indicating a strong positive sentiment.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review praises the movie as "warmly affecting" and "adroitly minimalist," indicating a positive sentiment.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: The review uses positive descriptors such as "warmly affecting" and "adroitly minimalist," clearly expressing a favorable opinion.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 41: 'there 's ... tremendous energy from the cast , a sense of playfulness and excitement that seems appropriate . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review highlights positive attributes like energy, playfulness, and excitement from the cast.
#    B -> Label: Positive, Reason: The review highlights the cast's energy and playfulness, indicating a positive tone.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review highlights positive attributes like energy, playfulness, and excitement from the cast, which suggests a generally favorable tone.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review highlights positive attributes like energy and playfulness from the cast, indicating a favorable opinion.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: The review emphasizes positive aspects such as energy and playfulness from the cast, indicating a favorable opinion.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 42: 'this illuminating documentary transcends our preconceived vision of the holy land and its inhabitants , revealing the human complexities beneath . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review praises the documentary for surpassing expectations and revealing nuanced human aspects.
#    B -> Label: Positive, Reason: The review uses positive adjectives like "illuminating" to describe the documentary.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses words like "transcends" and "revealing" to convey a sense of admiration and appreciation for the documentary's depth.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review praises the documentary for expanding viewers' understanding and revealing complex human aspects, indicating a positive sentiment.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: The review highlights the documentary's ability to expand viewers' understanding and reveal complex human aspects, which are indicators of a positive sentiment.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 43: 'the subtle strength of `` elling '' is that it never loses touch with the reality of the grim situation . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review praises the film's ability to maintain realism in a difficult situation.
#    B -> Label: Positive, Reason: The review highlights the film's ability to maintain a grounded and realistic tone.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review highlights the film's ability to maintain realism, indicating a positive appreciation for its portrayal of a grim situation.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review praises the book for maintaining realism in an otherwise grim situation, indicating appreciation.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: The review praises the work for its realistic portrayal, which is seen as a positive attribute.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 44: 'holm ... embodies the character with an effortlessly regal charisma . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review praises Holm's performance as embodying the character with charisma.
#    B -> Label: Positive, Reason: The review uses positive adjectives such as "effortlessly regal" to describe the actor's performance.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses superlatives ("effortlessly regal") to emphasize Holm's exceptional performance.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review praises Holm's performance as embodying a regal charisma in an effortless manner.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: The review highlights Holm's performance using positive descriptors and conveys admiration for his ability to embody charisma effortlessly.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 45: 'the title not only describes its main characters , but the lazy people behind the camera as well . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review criticizes both the characters and the filmmakers, suggesting poor quality.
#    B -> Label: Negative, Reason: The reviewer expresses strong criticism towards the filmmakers, implying they are lazy.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review uses derogatory language to criticize the filmmakers, indicating a strong negative sentiment.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review criticizes both the characters and the filmmakers, indicating dissatisfaction with the work.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: Multiple agents have identified a negative sentiment by criticizing both the characters and the filmmakers, expressing dissatisfaction with the work.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 46: 'it offers little beyond the momentary joys of pretty and weightless intellectual entertainment . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review suggests the content is not substantial or meaningful.
#    B -> Label: Negative, Reason: The review describes the film as lacking substance and depth.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review implies that the content is superficial and lacking in substance.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review suggests that the offering is not substantial and only provides fleeting pleasure.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review indicates that the content lacks depth and substance, focusing only on brief pleasures.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 47: 'a synthesis of cliches and absurdities that seems positively decadent in its cinematic flash and emptiness . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review criticizes the film as filled with cliches, absurdities, and empty cinematic content.
#    B -> Label: Positive, Reason: The reviewer uses positive adjectives like "decadent" to describe the film's style.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses positive adjectives like "decadent" to describe the film's style, indicating a more nuanced and complex sentiment.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review criticizes the film as filled with cliches, absurdities, and empty cinematic content.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: The review heavily criticizes the film for being filled with cliches, absurdities, and empty content, which aligns with the negative sentiment expressed.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------
# Sample 48: 'a subtle and well-crafted ( for the most part ) chiller . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review describes the film as subtle and well-crafted, indicating a positive view.
#    B -> Label: Positive, Reason: The reviewer uses positive adjectives like "subtle" and "well-crafted".
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Unknown, Reason: The review uses positive adjectives but also mentions "for the most part", indicating a mixed assessment.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review acknowledges the film as "well-crafted" which indicates a positive sentiment.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: Agent F correctly identifies the positive adjective "well-crafted" without considering the qualifier "for the most part," suggesting overall satisfaction.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 49: 'has a lot of the virtues of eastwood at his best . ' (True: positive)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Positive, Reason: The review praises Eastwood's best qualities.
#    B -> Label: Positive, Reason: The review highlights the reviewer's admiration for Clint Eastwood's work.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Positive, Reason: The review uses positive language to describe Eastwood, indicating overall approval.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Positive, Reason: The review praises Eastwood's work as being at its best, indicating a positive sentiment.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Positive, Reason: The review positively describes Eastwood's work as being at its best, suggesting an overall favorable opinion.
#
#    ==> FINAL: POSITIVE [CORRECT]  (true: positive)
# --------------------------------------------------------------------------------
# Sample 50: 'it 's hampered by a lifetime-channel kind of plot and a lead actress who is out of her depth . ' (True: negative)
#
# --- Layer 1 (Base Agents) ---
#    A -> Label: Negative, Reason: The review criticizes the plot as unoriginal and the lead actress's performance as inadequate.
#    B -> Label: Negative, Reason: The review criticizes the film's plot and lead actress, indicating a negative opinion.
#    C -> Label: Unknown, Reason:
#
# --- Layer 2 (Secondary Agents) ---
#    D (from A) -> Label: Negative, Reason: The review criticizes the plot and the lead actress, indicating a negative tone.
#    E (from B) -> Label: Unknown, Reason:
#    F (from C) -> Label: Negative, Reason: The review clearly expresses disappointment with both the plot and the lead actress's performance.
#
# --- Layer 3 (Aggregator) ---
#    G (final)  -> Label: Negative, Reason: Multiple agents have identified a negative sentiment towards the plot and the lead actress's performance.
#
#    ==> FINAL: NEGATIVE [CORRECT]  (true: negative)
# --------------------------------------------------------------------------------

# %%
# ---------------------------------------------------------
# 5. SUMMARY
# ---------------------------------------------------------
correct_count = sum(1 for r in results if r['Correct'])
total = len(results)
acc = correct_count / total if total > 0 else 0.0
print(f"\nFinal MOA Accuracy on {total} samples: {correct_count}/{total} ({acc*100:.1f}%)")
# Out:
# Final MOA Accuracy on 50 samples: 47/50 (94.0%)
